# %%
from pathlib import Path
path = Path('/home/alilavaee/Desktop/PlantifyDr/PlantDiseasesDataset')

# %%
# Download dataset with Kaggle API
# ! kaggle datasets download lavaman151/plantifydr-dataset --unzip

# %%
from fastai.vision.all import *

# %%
path.ls()
# Out:
# (#10) [Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Bell pepper'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Corn'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Grape'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Strawberry'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Citrus'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Tomato'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Cherry'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Peach'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Potato'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Apple')]

# %%
plant_list = ['Apple','Bell pepper','Cherry','Citrus','Corn','Grape','Peach','Potato','Strawberry','Tomato']
plant = 'Strawberry'

# %%
model_path = Path(path/plant)

# %%
batch_tfms=[Normalize.from_stats(*imagenet_stats)]

# %%
dls = ImageDataLoaders.from_folder(path/plant,train='train',valid_pct=0.2,seed=1000,item_tfms=Resize(224),
                                   batch_tfms=batch_tfms,bs=128)

# %%
dls.show_batch(figsize=(15,15))

# %%
f1 = F1Score(average='weighted')
mcc = MatthewsCorrCoef()

# %%
learn = cnn_learner(dls, models.resnet50,loss_func=LabelSmoothingCrossEntropy(),metrics=[accuracy,f1,mcc],
                    cbs=[SaveModelCallback(monitor='accuracy'),EarlyStoppingCallback(monitor='accuracy',patience=2)
                         ,ShowGraphCallback()],model_dir=model_path/'models').to_fp16()

# %%
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.536393</td>
#       <td>0.444704</td>
#       <td>0.998375</td>
#       <td>0.998375</td>
#       <td>0.996716</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.435053</td>
#       <td>0.313800</td>
#       <td>0.996751</td>
#       <td>0.996752</td>
#       <td>0.993451</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.371206</td>
#       <td>0.264880</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.333514</td>
#       <td>0.248149</td>
#       <td>0.999188</td>
#       <td>0.999188</td>
#       <td>0.998357</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.296516</td>
#       <td>0.220358</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9983752965927124.
# Better model found at epoch 2 with accuracy value: 1.0.
# No improvement since epoch 2: early stopping

# %%
learn.fine_tune(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.315690</td>
#       <td>0.281918</td>
#       <td>0.990252</td>
#       <td>0.990252</td>
#       <td>0.980273</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9902518391609192.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.264322</td>
#       <td>0.236031</td>
#       <td>0.999188</td>
#       <td>0.999188</td>
#       <td>0.998357</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.243405</td>
#       <td>0.207641</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.229603</td>
#       <td>0.207212</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.222391</td>
#       <td>0.206467</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9991876482963562.
# Better model found at epoch 1 with accuracy value: 1.0.
# No improvement since epoch 1: early stopping

# %%
learn = learn.to_fp32()

# %%
learn.save(model_path/f'models/{plant}')
# Out:
# Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Strawberry/models/Strawberry.pth')

# %%
learn = cnn_learner(dls, models.resnet50).load(model_path/f'models/{plant}')

# %%
learn.summary()
# Out:
# Sequential (Input shape: 128)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      128 x 64 x 112 x 11
# Conv2d                                    9408       False
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    4096       False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 64 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 64 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 56 x 56
# Conv2d                                    32768      False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    131072     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 28 x 28
# Conv2d                                    131072     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    524288     False
# BatchNorm2d                               2048       True
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 14 x 14
# Conv2d                                    524288     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    2097152    False
# BatchNorm2d                               4096       True
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# Flatten
# BatchNorm1d                               8192       True
# Dropout
# ____________________________________________________________________________
#                      128 x 512
# Linear                                    2097152    True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      128 x 2
# Linear                                    1024       True
# ____________________________________________________________________________
#
# Total params: 25,615,424
# Total trainable params: 2,160,512
# Total non-trainable params: 23,454,912
#
# Optimizer used: <function Adam at 0x7f29f09f65e0>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model frozen up to parameter group #2
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.show_results(max_n=16)

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
interp.plot_confusion_matrix(figsize=(12,12))

# %%
learn.export(f'{plant}.pkl')
