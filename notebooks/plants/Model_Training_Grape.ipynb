# %%
from pathlib import Path
path = Path('/home/alilavaee/Desktop/PlantifyDr/PlantDiseasesDataset')

# %%
# Download dataset with Kaggle API
# ! kaggle datasets download lavaman151/plantifydr-dataset --unzip

# %%
from fastai.vision.all import *

# %%
path.ls()
# Out:
# (#10) [Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Bell pepper'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Corn'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Grape'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Strawberry'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Citrus'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Tomato'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Cherry'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Peach'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Potato'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Apple')]

# %%
plant_list = ['Apple','Bell pepper','Cherry','Citrus','Corn','Grape','Peach','Potato','Strawberry','Tomato']
plant = 'Grape'

# %%
model_path = Path(path/plant)

# %%
batch_tfms=[Normalize.from_stats(*imagenet_stats)]

# %%
dls = ImageDataLoaders.from_folder(path/plant,train='train',valid_pct=0.2,seed=1000,item_tfms=Resize(224),
                                   batch_tfms=batch_tfms,bs=128)

# %%
dls.show_batch(figsize=(15,15))

# %%
f1 = F1Score(average='weighted')
mcc = MatthewsCorrCoef()

# %%
learn = cnn_learner(dls, models.resnet50,loss_func=LabelSmoothingCrossEntropy(),metrics=[accuracy,f1,mcc],
                    cbs=[SaveModelCallback(monitor='accuracy'),EarlyStoppingCallback(monitor='accuracy',patience=2)
                         ,ShowGraphCallback()],model_dir=model_path/'models').to_fp16()

# %%
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.795930</td>
#       <td>0.544532</td>
#       <td>0.978836</td>
#       <td>0.978842</td>
#       <td>0.971535</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.628981</td>
#       <td>0.468158</td>
#       <td>0.988662</td>
#       <td>0.988655</td>
#       <td>0.984753</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.541311</td>
#       <td>0.441907</td>
#       <td>0.995843</td>
#       <td>0.995841</td>
#       <td>0.994412</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.473779</td>
#       <td>0.411355</td>
#       <td>0.998488</td>
#       <td>0.998488</td>
#       <td>0.997968</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.425257</td>
#       <td>0.375409</td>
#       <td>0.997355</td>
#       <td>0.997353</td>
#       <td>0.996444</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.396785</td>
#       <td>0.371415</td>
#       <td>0.998110</td>
#       <td>0.998110</td>
#       <td>0.997460</td>
#       <td>00:33</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9788359999656677.
# Better model found at epoch 1 with accuracy value: 0.9886621236801147.
# Better model found at epoch 2 with accuracy value: 0.9958427548408508.
# Better model found at epoch 3 with accuracy value: 0.9984883069992065.
# No improvement since epoch 3: early stopping

# %%
learn.fine_tune(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.422041</td>
#       <td>0.391398</td>
#       <td>0.996977</td>
#       <td>0.996975</td>
#       <td>0.995935</td>
#       <td>00:33</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9969765543937683.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.387548</td>
#       <td>0.376625</td>
#       <td>0.997732</td>
#       <td>0.997731</td>
#       <td>0.996951</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.377660</td>
#       <td>0.362688</td>
#       <td>0.999622</td>
#       <td>0.999622</td>
#       <td>0.999492</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.369101</td>
#       <td>0.361988</td>
#       <td>0.997732</td>
#       <td>0.997730</td>
#       <td>0.996957</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.364549</td>
#       <td>0.357161</td>
#       <td>0.997732</td>
#       <td>0.997731</td>
#       <td>0.996953</td>
#       <td>00:43</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.997732400894165.
# Better model found at epoch 1 with accuracy value: 0.9996220469474792.
# No improvement since epoch 1: early stopping

# %%
learn = learn.to_fp32()

# %%
learn.save(model_path/f'models/{plant}')
# Out:
# Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Grape/models/Grape.pth')

# %%
learn = cnn_learner(dls, models.resnet50).load(model_path/f'models/{plant}')

# %%
learn.summary()
# Out:
# Sequential (Input shape: 128)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      128 x 64 x 112 x 11
# Conv2d                                    9408       False
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    4096       False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 64 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 64 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 56 x 56
# Conv2d                                    32768      False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    131072     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 28 x 28
# Conv2d                                    131072     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    524288     False
# BatchNorm2d                               2048       True
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 14 x 14
# Conv2d                                    524288     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    2097152    False
# BatchNorm2d                               4096       True
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# Flatten
# BatchNorm1d                               8192       True
# Dropout
# ____________________________________________________________________________
#                      128 x 512
# Linear                                    2097152    True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      128 x 4
# Linear                                    2048       True
# ____________________________________________________________________________
#
# Total params: 25,616,448
# Total trainable params: 2,161,536
# Total non-trainable params: 23,454,912
#
# Optimizer used: <function Adam at 0x7fa97c1f4790>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model frozen up to parameter group #2
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.show_results(max_n=16)

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
interp.plot_confusion_matrix(figsize=(12,12))

# %%
learn.export(f'{plant}.pkl')
