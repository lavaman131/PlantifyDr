# %%
from pathlib import Path
path = Path('/home/alilavaee/Desktop/PlantifyDr/PlantDiseasesDataset')

# %%
# Download dataset with Kaggle API
# ! kaggle datasets download lavaman151/plantifydr-dataset --unzip

# %%
from fastai.vision.all import *

# %%
path.ls()
# Out:
# (#10) [Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Bell pepper'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Corn'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Grape'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Strawberry'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Citrus'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Tomato'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Cherry'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Peach'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Potato'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Apple')]

# %%
plant_list = ['Apple','Bell pepper','Cherry','Citrus','Corn','Grape','Peach','Potato','Strawberry','Tomato']
plant = 'Potato'

# %%
model_path = Path(path/plant)

# %%
batch_tfms=[Normalize.from_stats(*imagenet_stats)]

# %%
dls = ImageDataLoaders.from_folder(path/plant,train='train',valid_pct=0.2,seed=1000,item_tfms=Resize(224),
                                   batch_tfms=batch_tfms,bs=128)

# %%
dls.show_batch(figsize=(15,15))

# %%
f1 = F1Score(average='weighted')
mcc = MatthewsCorrCoef()

# %%
learn = cnn_learner(dls, models.resnet50,loss_func=LabelSmoothingCrossEntropy(),metrics=[accuracy,f1,mcc],
                    cbs=[SaveModelCallback(monitor='accuracy'),EarlyStoppingCallback(monitor='accuracy',patience=2)
                         ,ShowGraphCallback()],model_dir=model_path/'models').to_fp16()

# %%
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.768865</td>
#       <td>0.547094</td>
#       <td>0.974238</td>
#       <td>0.974268</td>
#       <td>0.960758</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.601907</td>
#       <td>0.440493</td>
#       <td>0.984227</td>
#       <td>0.984204</td>
#       <td>0.975977</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.510966</td>
#       <td>0.384069</td>
#       <td>0.987907</td>
#       <td>0.987914</td>
#       <td>0.981592</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.448270</td>
#       <td>0.362498</td>
#       <td>0.988959</td>
#       <td>0.988953</td>
#       <td>0.983179</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.398087</td>
#       <td>0.337606</td>
#       <td>0.991588</td>
#       <td>0.991585</td>
#       <td>0.987174</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.362325</td>
#       <td>0.321722</td>
#       <td>0.990536</td>
#       <td>0.990532</td>
#       <td>0.985570</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.339770</td>
#       <td>0.317631</td>
#       <td>0.990536</td>
#       <td>0.990532</td>
#       <td>0.985570</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9742376208305359.
# Better model found at epoch 1 with accuracy value: 0.9842271208763123.
# Better model found at epoch 2 with accuracy value: 0.9879074692726135.
# Better model found at epoch 3 with accuracy value: 0.988959014415741.
# Better model found at epoch 4 with accuracy value: 0.9915878176689148.
# No improvement since epoch 4: early stopping

# %%
learn.fine_tune(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.355781</td>
#       <td>0.339992</td>
#       <td>0.990536</td>
#       <td>0.990530</td>
#       <td>0.985570</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9905362725257874.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.329262</td>
#       <td>0.319144</td>
#       <td>0.991588</td>
#       <td>0.991588</td>
#       <td>0.987168</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.321343</td>
#       <td>0.317947</td>
#       <td>0.990010</td>
#       <td>0.990005</td>
#       <td>0.984764</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.312297</td>
#       <td>0.309941</td>
#       <td>0.993165</td>
#       <td>0.993165</td>
#       <td>0.989573</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.305749</td>
#       <td>0.307069</td>
#       <td>0.991588</td>
#       <td>0.991588</td>
#       <td>0.987166</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.301865</td>
#       <td>0.307032</td>
#       <td>0.992639</td>
#       <td>0.992639</td>
#       <td>0.988772</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9915878176689148.
# Better model found at epoch 2 with accuracy value: 0.9931650757789612.
# No improvement since epoch 2: early stopping

# %%
learn = learn.to_fp32()

# %%
learn.save(model_path/f'models/{plant}')
# Out:
# Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Potato/models/Potato.pth')

# %%
learn = cnn_learner(dls, models.resnet50).load(model_path/f'models/{plant}')

# %%
learn.summary()
# Out:
# Sequential (Input shape: 128)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      128 x 64 x 112 x 11
# Conv2d                                    9408       False
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    4096       False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 64 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 64 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 56 x 56
# Conv2d                                    32768      False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    131072     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 28 x 28
# Conv2d                                    131072     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    524288     False
# BatchNorm2d                               2048       True
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 14 x 14
# Conv2d                                    524288     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    2097152    False
# BatchNorm2d                               4096       True
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# Flatten
# BatchNorm1d                               8192       True
# Dropout
# ____________________________________________________________________________
#                      128 x 512
# Linear                                    2097152    True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      128 x 3
# Linear                                    1536       True
# ____________________________________________________________________________
#
# Total params: 25,615,936
# Total trainable params: 2,161,024
# Total non-trainable params: 23,454,912
#
# Optimizer used: <function Adam at 0x7f9e782e4700>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model frozen up to parameter group #2
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.show_results(max_n=16)

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
interp.plot_confusion_matrix(figsize=(12,12))

# %%
learn.export(f'{plant}.pkl')
