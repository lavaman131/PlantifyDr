# %%
from pathlib import Path
path = Path('/home/alilavaee/Desktop/PlantifyDr/PlantDiseasesDataset')

# %%
# Download dataset with Kaggle API
# ! kaggle datasets download lavaman151/plantifydr-dataset --unzip

# %%
from fastai.vision.all import *

# %%
path.ls()
# Out:
# (#10) [Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Bell pepper'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Corn'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Grape'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Strawberry'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Citrus'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Tomato'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Cherry'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Peach'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Potato'),Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Apple')]

# %%
plant_list = ['Apple','Bell pepper','Cherry','Citrus','Corn','Grape','Peach','Potato','Strawberry','Tomato']
plant = 'Apple'

# %%
model_path = Path(path/plant)

# %%
batch_tfms=[Normalize.from_stats(*imagenet_stats)]

# %%
dls = ImageDataLoaders.from_folder(path/plant,train='train',valid_pct=0.2,seed=1000,item_tfms=Resize(224),
                                   batch_tfms=batch_tfms,bs=128)

# %%
dls.show_batch(figsize=(15,15))

# %%
f1 = F1Score(average='weighted')
mcc = MatthewsCorrCoef()

# %%
learn = cnn_learner(dls, models.resnet50,loss_func=LabelSmoothingCrossEntropy(),metrics=[accuracy,f1,mcc],
                    cbs=[SaveModelCallback(monitor='accuracy'),EarlyStoppingCallback(monitor='accuracy',patience=2)
                         ,ShowGraphCallback()],model_dir=model_path/'models').to_fp16()

# %%
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.838682</td>
#       <td>0.567532</td>
#       <td>0.975304</td>
#       <td>0.975313</td>
#       <td>0.966671</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.662786</td>
#       <td>0.508716</td>
#       <td>0.989362</td>
#       <td>0.989368</td>
#       <td>0.985652</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.572266</td>
#       <td>0.451348</td>
#       <td>0.993921</td>
#       <td>0.993909</td>
#       <td>0.991802</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.494551</td>
#       <td>0.410602</td>
#       <td>0.995441</td>
#       <td>0.995434</td>
#       <td>0.993850</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.435928</td>
#       <td>0.384028</td>
#       <td>0.995821</td>
#       <td>0.995815</td>
#       <td>0.994364</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.403588</td>
#       <td>0.372371</td>
#       <td>0.996581</td>
#       <td>0.996576</td>
#       <td>0.995386</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.386116</td>
#       <td>0.366775</td>
#       <td>0.996581</td>
#       <td>0.996577</td>
#       <td>0.995387</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.376039</td>
#       <td>0.364845</td>
#       <td>0.996201</td>
#       <td>0.996196</td>
#       <td>0.994875</td>
#       <td>00:33</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9753039479255676.
# Better model found at epoch 1 with accuracy value: 0.9893617033958435.
# Better model found at epoch 2 with accuracy value: 0.9939209818840027.
# Better model found at epoch 3 with accuracy value: 0.9954407215118408.
# Better model found at epoch 4 with accuracy value: 0.9958206415176392.
# Better model found at epoch 5 with accuracy value: 0.9965805411338806.
# No improvement since epoch 5: early stopping

# %%
learn.fine_tune(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.386689</td>
#       <td>0.384529</td>
#       <td>0.996581</td>
#       <td>0.996578</td>
#       <td>0.995392</td>
#       <td>00:33</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9965805411338806.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.374363</td>
#       <td>0.366520</td>
#       <td>0.996581</td>
#       <td>0.996577</td>
#       <td>0.995392</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.367760</td>
#       <td>0.365704</td>
#       <td>0.996201</td>
#       <td>0.996197</td>
#       <td>0.994879</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.361047</td>
#       <td>0.359280</td>
#       <td>0.996581</td>
#       <td>0.996580</td>
#       <td>0.995389</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9965805411338806.
# No improvement since epoch 0: early stopping

# %%
learn = learn.to_fp32()

# %%
learn.save(model_path/f'models/{plant}')
# Out:
# Path('/home/alilavaee/Desktop/plantifydr/PlantDiseasesDataset/Apple/models/Apple.pth')

# %%
learn = cnn_learner(dls, models.resnet50).load(model_path/f'models/{plant}')

# %%
learn.summary()
# Out:
# Sequential (Input shape: 128)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      128 x 64 x 112 x 11
# Conv2d                                    9408       False
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    4096       False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 64 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 64 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      128 x 256 x 56 x 56
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 56 x 56
# Conv2d                                    32768      False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    131072     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 128 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      128 x 512 x 28 x 28
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 28 x 28
# Conv2d                                    131072     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    524288     False
# BatchNorm2d                               2048       True
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 256 x 14 x 14
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      128 x 1024 x 14 x 1
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 14 x 14
# Conv2d                                    524288     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    2097152    False
# BatchNorm2d                               4096       True
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      128 x 512 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      128 x 2048 x 7 x 7
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# Flatten
# BatchNorm1d                               8192       True
# Dropout
# ____________________________________________________________________________
#                      128 x 512
# Linear                                    2097152    True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      128 x 4
# Linear                                    2048       True
# ____________________________________________________________________________
#
# Total params: 25,616,448
# Total trainable params: 2,161,536
# Total non-trainable params: 23,454,912
#
# Optimizer used: <function Adam at 0x7f199b168790>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model frozen up to parameter group #2
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.show_results(max_n=16)

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
interp.plot_confusion_matrix(figsize=(12,12))

# %%
learn.export(f'{plant}.pkl')
